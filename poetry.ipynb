# %% [markdown]
# # ROBERT LEE FROST (March 26, 1874 - January 29, 1963)
# ## Robert Frost  was an American poet who became famous for his poetry's engagement with New England locales, identities, and themes.
# <img src='https://upload.wikimedia.org/wikipedia/commons/3/36/Robert_Frost%2C_1910s.jpg'>

# %% [markdown]
# ## The Road Not Taken
# ### This classic narrative poem by Robert Frost was published in 1916. It was the first poem in his Mountain Interval collection. It's central theme is the divergence of paths, both literally and figuratively, although its interpretation is noted for being complex and potentially divergent.

# %%
# Listen to the poem on YouTube
from IPython.display import YouTubeVideo
YouTubeVideo('KUaQgRiJukA')

# %%
# WALT WHITMAN (May 31, 1819 - March 26, 1892)
## Whitman is among the most influential poets in the American canon, often called the father of free verse.
<img src='https://cdn.britannica.com/80/26880-050-CEB5F414/Walt-Whitman-photograph-Mathew-Brady.jpg'>

# %%
# YouTube Video - Song of the Open Road
YouTubeVideo('bCgbc_RcKF8')
